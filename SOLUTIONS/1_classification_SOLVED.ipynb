# %% [markdown]
# # Introduction to data science: classification
#
# [**This notebook is available on Google Colab.**](https://colab.research.google.com/drive/1EcvFm-NiPqzysCrmYLaCm5Ez_TLzw9bt)
#
# You know about the _data_ side of **data science**, now we can find out about the _science_ :)
#
# Data science depends hugely on data, but the _science_ part requires us to select the best (i.e. optimal) model -- and this means having an objective measure of 'best' and a way to prove that you have found it.
#
# In this notebook, we will predict the **lithology** (a fancy name for rock type) from two physical measurements: P-wave velocity (Vp) and bulk density (rho). We will fit a **support vector machine**, a versatile learning algorithm.
#
# First we'll import some data. I'm using an extract from the Rock Property Catalog, https://github.com/scienxlab/datasets/tree/main/rpc

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/scienxlab/datasets/refs/heads/main/rpc/rpc-3-imbalanced.csv'

df = pd.read_csv(url)

df.head()
# Out:
#       RPC                            Description Lithology           Vp  \
# 0  101023                             Gray Shale     shale  4953.660011
# 1  100978                        Olentangy Shale     shale  3444.658279
# 2  100993                        Brown Gas Shale     shale  3507.803917
# 3  101048  Shale 2 (Density is assumed constant)     shale  2988.889933
# 4  100417                        Tight gas shale     shale  3642.000000
#
#             Vs   Rho
# 0  2957.260132  2.71
# 1  2318.002224  2.68
# 2  2218.529940  2.56
# 3  1633.329988  2.60
# 4  2221.000000  2.46

# %%
df.describe() # 12 missing values in the Rho column, we should drop those
# Out:
#                  RPC           Vp           Vs         Rho
# count     440.000000   440.000000   440.000000  428.000000
# mean   101420.745455  4241.400263  2404.569500    2.471570
# std       817.462173  1017.116305   623.491742    0.168254
# min    100031.000000  1490.711927   839.570000    1.770000
# 25%    100831.750000  3444.243709  2008.362500    2.387500
# 50%    101589.000000  4396.045268  2559.060000    2.510000
# 75%    102179.250000  5150.920000  2858.632148    2.570000
# max    102855.000000  5940.000000  3477.690000    2.780000

# %%
df = df.dropna()

# %%
features = ['Vp', 'Rho']
target = 'Lithology'

X = df[features].values
y = df[target].values

# %%
X
# Out:
# array([[4.95366001e+03, 2.71000004e+00],
#        [3.44465828e+03, 2.68000007e+00],
#        [3.50780392e+03, 2.55999994e+00],
#        [2.98888993e+03, 2.60000000e+00],
#        [3.64200000e+03, 2.46000000e+00],
#        [4.98706818e+03, 2.71000004e+00],
#        [4.39576054e+03, 2.50999999e+00],
#        [3.81902075e+03, 2.62600000e+00],
#        [3.03332996e+03, 2.60000000e+00],
#        [2.40273833e+03, 2.35400000e+00],
#        [2.20200000e+03, 2.25000000e+00],
#        [3.89310288e+03, 2.55999994e+00],
#        [2.50911665e+03, 2.35400000e+00],
#        [3.54500000e+03, 2.50000000e+00],
#        [3.72675133e+03, 2.60500000e+00],
#        [3.75062180e+03, 2.68000007e+00],
#        [3.96597624e+03, 2.62700000e+00],
#        [5.25846000e+03, 2.55000000e+00],
#        [3.66900000e+03, 2.59000000e+00],
#        [4.40883350e+03, 2.59700000e+00],
#        [3.04800000e+03, 2.42000000e+00],
#        [1.49071193e+03, 2.29500008e+00],
#        [5.19100000e+03, 2.78000000e+00],
#        [4.40400000e+03, 2.31000000e+00],
#        [3.85000000e+03, 2.48000000e+00],
#        [3.23806644e+03, 2.68000007e+00],
#        [4.72278404e+03, 2.55999994e+00],
#        [3.78716636e+03, 2.50999999e+00],
#        [4.48463392e+03, 2.68000007e+00],
#        [5.06982517e+03, 2.55999994e+00],
#        [3.04444003e+03, 2.60000000e+00],
#        [4.31934214e+03, 2.68000007e+00],
#        [5.32042000e+03, 2.55000000e+00],
#        [2.88889003e+03, 2.60000000e+00],
#        [3.92154121e+03, 2.50999999e+00],
#        [3.79298306e+03, 2.56000000e+00],
#        [2.29084086e+03, 2.31900000e+00],
#        [2.86000000e+03, 2.27000000e+00],
#        [2.98000000e+03, 2.09000000e+00],
#        [3.23511219e+03, 2.51100000e+00],
#        [3.44209337e+03, 2.40800000e+00],
#        [2.74085665e+03, 2.44000000e+00],
#        [3.19883704e+03, 2.40800000e+00],
#        [4.79257250e+03, 2.55999994e+00],
#        [4.02483082e+03, 2.71000004e+00],
#        [4.13000000e+03, 2.64000000e+00],
#        [3.85493946e+03, 2.50999999e+00],
#        [3.04300000e+03, 2.49200000e+00],
#        [4.99392000e+03, 2.55000000e+00],
#        [3.02407002e+03, 2.60000000e+00],
#        [2.84443998e+03, 2.60000000e+00],
#        [2.53200000e+03, 2.26000000e+00],
#        [3.73600000e+03, 2.59000000e+00],
#        [3.11900000e+03, 2.39000000e+00],
#        [3.79400000e+03, 2.56000000e+00],
#        [3.47600000e+03, 2.59000000e+00],
#        [3.11788821e+03, 2.51100000e+00],
#        [4.77376652e+03, 2.50999999e+00],
#        [3.14443994e+03, 2.60000000e+00],
#        [3.00100000e+03, 2.50000000e+00],
#        [2.80900000e+03, 2.39000000e+00],
#        [4.26590204e+03, 2.59700000e+00],
#        [4.72100000e+03, 2.64000000e+00],
#        [3.42800000e+03, 2.39000000e+00],
#        [3.72870946e+03, 2.62600000e+00],
#        [3.90000000e+03, 2.60000000e+00],
#        [5.24400000e+03, 2.78000000e+00],
#        [3.37300000e+03, 2.40000000e+00],
#        [4.85229588e+03, 2.68000007e+00],
#        [4.15120125e+03, 2.71000004e+00],
#        [3.38000000e+03, 2.22000000e+00],
#        [3.85352278e+03, 2.62700000e+00],
#        [3.55200000e+03, 2.59000000e+00],
#        [3.73719001e+03, 2.57400000e+00],
#        [3.83708835e+03, 2.71000004e+00],
#        [3.87953353e+03, 2.56000000e+00],
#        [5.02233791e+03, 2.68000007e+00],
#        [5.20700000e+03, 2.78000000e+00],
#        [3.73434234e+03, 2.55999994e+00],
#        [3.93600000e+03, 2.58000000e+00],
#        [3.00300000e+03, 2.39000000e+00],
#        [3.37410951e+03, 2.53500000e+00],
#        [2.94136691e+03, 2.44000000e+00],
#        [5.21791000e+03, 2.55000000e+00],
#        [2.87900000e+03, 2.39000000e+00],
#        [4.66400957e+03, 2.50999999e+00],
#        [4.21000000e+03, 2.55000000e+00],
#        [3.66951585e+03, 2.52500010e+00],
#        [3.06600000e+03, 2.51000000e+00],
#        [2.40919614e+03, 2.31900000e+00],
#        [2.81317162e+03, 2.44000000e+00],
#        [3.20900000e+03, 2.39000000e+00],
#        [3.92800000e+03, 2.59000000e+00],
#        [3.66508341e+03, 2.68000007e+00],
#        [3.44300000e+03, 2.51600000e+00],
#        [3.29000000e+03, 2.35000000e+00],
#        [5.07300000e+03, 2.68000000e+00],
#        [2.74500000e+03, 2.34000000e+00],
#        [3.75016594e+03, 2.50999999e+00],
#        [3.60200000e+03, 2.59000000e+00],
#        [3.61200000e+03, 2.47000000e+00],
#        [3.54080677e+03, 2.68000007e+00],
#        [3.50223136e+03, 2.55999994e+00],
#        [3.07778001e+03, 2.60000000e+00],
#        [2.86799741e+03, 2.44000000e+00],
#        [4.06738043e+03, 2.62700000e+00],
#        [3.78906393e+03, 2.60500000e+00],
#        [3.82732773e+03, 2.55999994e+00],
#        [3.12000000e+03, 2.50000000e+00],
#        [3.29600000e+03, 2.49000000e+00],
#        [3.77700000e+03, 2.59000000e+00],
#        [5.26700000e+03, 2.78000000e+00],
#        [3.70335579e+03, 2.56000000e+00],
#        [3.53100000e+03, 2.45000000e+00],
#        [4.27108717e+03, 2.55999994e+00],
#        [4.87697267e+03, 2.50999999e+00],
#        [2.90200000e+03, 2.13000000e+00],
#        [3.43600000e+03, 2.50000000e+00],
#        [3.46667004e+03, 2.60000000e+00],
#        [3.51000000e+03, 2.34000000e+00],
#        [3.36090493e+03, 2.40800000e+00],
#        [3.72000000e+03, 2.38000000e+00],
#        [3.29100000e+03, 2.39000000e+00],
#        [4.12491512e+03, 2.68000007e+00],
#        [3.53700000e+03, 2.47000000e+00],
#        [3.31416225e+03, 2.51100000e+00],
#        [3.21400000e+03, 2.42000000e+00],
#        [4.52900000e+03, 2.52000000e+00],
#        [3.36100000e+03, 2.39000000e+00],
#        [4.15800000e+03, 2.56700000e+00],
#        [3.35356712e+03, 2.43900000e+00],
#        [3.52200000e+03, 2.41000000e+00],
#        [2.61500000e+03, 2.18000000e+00],
#        [4.37621880e+03, 2.71000004e+00],
#        [4.64615059e+03, 2.71000004e+00],
#        [3.24600000e+03, 2.59000000e+00],
#        [2.42950225e+03, 2.33800006e+00],
#        [3.22282290e+03, 2.53500000e+00],
#        [4.61583900e+03, 2.68000007e+00],
#        [2.53019142e+03, 2.35400000e+00],
#        [3.39200000e+03, 2.59000000e+00],
#        [4.92101812e+03, 2.68000007e+00],
#        [3.08100000e+03, 2.45000000e+00],
#        [3.83938575e+03, 2.60500000e+00],
#        [2.93333006e+03, 2.60000000e+00],
#        [4.53406763e+03, 2.50999999e+00],
#        [4.33396006e+03, 2.59700000e+00],
#        [3.91190886e+03, 2.57400000e+00],
#        [3.77406168e+03, 2.71000004e+00],
#        [4.61400700e+03, 2.55999994e+00],
#        [5.18194866e+03, 2.50999999e+00],
#        [1.67211866e+03, 2.28900003e+00],
#        [4.21296549e+03, 2.71000004e+00],
#        [3.08017778e+03, 2.43900000e+00],
#        [4.41056967e+03, 2.55999994e+00],
#        [5.17200000e+03, 2.78000000e+00],
#        [4.17327833e+03, 2.59700000e+00],
#        [4.45146036e+03, 2.71000004e+00],
#        [4.22476101e+03, 2.50999999e+00],
#        [3.46000000e+03, 2.33000000e+00],
#        [3.88000000e+03, 2.49000000e+00],
#        [3.04800000e+03, 2.42000000e+00],
#        [3.51200000e+03, 2.45000000e+00],
#        [5.28400000e+03, 2.78000000e+00],
#        [3.37943316e+03, 2.49900000e+00],
#        [3.48000000e+03, 2.48000000e+00],
#        [3.95693946e+03, 2.50999999e+00],
#        [3.77489185e+03, 2.62600000e+00],
#        [3.37700000e+03, 2.42000000e+00],
#        [4.75216007e+03, 2.71000004e+00],
#        [5.18100000e+03, 2.78000000e+00],
#        [3.87052464e+03, 2.62600000e+00],
#        [2.98970389e+03, 2.56200004e+00],
#        [3.73067141e+03, 2.68000007e+00],
#        [2.44913769e+03, 2.31900000e+00],
#        [3.90235901e+03, 2.60500000e+00],
#        [2.90000009e+03, 2.60000000e+00],
#        [3.57399464e+03, 2.55999994e+00],
#        [5.13489914e+03, 2.55999994e+00],
#        [3.21499658e+03, 2.43900000e+00],
#        [3.06750607e+03, 2.71000004e+00],
#        [4.29600000e+03, 2.66000000e+00],
#        [4.97803927e+03, 2.50999999e+00],
#        [3.28750801e+03, 2.43900000e+00],
#        [5.18048000e+03, 2.55000000e+00],
#        [3.44184009e+03, 2.60000000e+00],
#        [5.15953000e+03, 2.55000000e+00],
#        [1.69471610e+03, 2.29800010e+00],
#        [4.54984713e+03, 2.71000004e+00],
#        [2.35763240e+03, 2.31900000e+00],
#        [2.46470404e+03, 2.35400000e+00],
#        [4.16700000e+03, 2.31000000e+00],
#        [3.86288452e+03, 2.55999994e+00],
#        [3.45300000e+03, 2.39000000e+00],
#        [3.00409555e+03, 2.44000000e+00],
#        [5.26700000e+03, 2.78000000e+00],
#        [3.53600000e+03, 2.43000000e+00],
#        [5.09242916e+03, 2.68000007e+00],
#        [3.32464337e+03, 2.53500000e+00],
#        [5.07709503e+03, 2.50999999e+00],
#        [2.97080000e+03, 2.12000000e+00],
#        [3.12139000e+03, 2.16000000e+00],
#        [2.97080000e+03, 2.16000000e+00],
#        [2.92782000e+03, 2.14000000e+00],
#        [2.58333000e+03, 2.09000000e+00],
#        [3.31529000e+03, 2.34000000e+00],
#        [3.58432000e+03, 2.25000000e+00],
#        [2.91699000e+03, 2.18000000e+00],
#        [2.88484000e+03, 2.12000000e+00],
#        [3.53051000e+03, 2.27000000e+00],
#        [2.61549000e+03, 2.13000000e+00],
#        [3.37992000e+03, 2.39000000e+00],
#        [2.64797000e+03, 1.77000000e+00],
#        [2.61549000e+03, 1.91000000e+00],
#        [2.45407000e+03, 1.91000000e+00],
#        [2.36811000e+03, 1.91000000e+00],
#        [2.70177000e+03, 1.94000000e+00],
#        [2.49705000e+03, 1.87000000e+00],
#        [2.82021000e+03, 1.91000000e+00],
#        [2.68012000e+03, 1.90000000e+00],
#        [2.76640000e+03, 1.94000000e+00],
#        [2.51870000e+03, 1.99000000e+00],
#        [2.58333000e+03, 1.97000000e+00],
#        [2.79856000e+03, 2.00000000e+00],
#        [2.89534000e+03, 1.98000000e+00],
#        [3.02461000e+03, 2.10000000e+00],
#        [2.69094000e+03, 2.10000000e+00],
#        [3.14304000e+03, 2.14000000e+00],
#        [4.26509000e+03, 2.34000000e+00],
#        [5.70866000e+03, 2.69000000e+00],
#        [4.85564000e+03, 2.44000000e+00],
#        [4.98688000e+03, 2.57000000e+00],
#        [5.54462000e+03, 2.57000000e+00],
#        [4.98688000e+03, 2.57000000e+00],
#        [4.46194000e+03, 2.34000000e+00],
#        [5.21654000e+03, 2.53000000e+00],
#        [5.77428000e+03, 2.56000000e+00],
#        [5.28215000e+03, 2.44000000e+00],
#        [5.74147000e+03, 2.64000000e+00],
#        [5.74147000e+03, 2.56000000e+00],
#        [4.00262000e+03, 2.34000000e+00],
#        [5.05249000e+03, 2.53000000e+00],
#        [5.31496000e+03, 2.64000000e+00],
#        [5.57743000e+03, 2.56000000e+00],
#        [4.62598000e+03, 2.37000000e+00],
#        [4.52756000e+03, 2.31000000e+00],
#        [5.31496000e+03, 2.53000000e+00],
#        [5.61024000e+03, 2.44000000e+00],
#        [5.24934000e+03, 2.44000000e+00],
#        [5.70866000e+03, 2.56000000e+00],
#        [4.69160000e+03, 2.53000000e+00],
#        [5.67585000e+03, 2.69000000e+00],
#        [4.39633000e+03, 2.53000000e+00],
#        [5.47900000e+03, 2.53000000e+00],
#        [5.21654000e+03, 2.69000000e+00],
#        [5.24934000e+03, 2.44000000e+00],
#        [4.92126000e+03, 2.44000000e+00],
#        [5.57743000e+03, 2.69000000e+00],
#        [4.98688000e+03, 2.53000000e+00],
#        [4.62598000e+03, 2.31000000e+00],
#        [4.95407000e+03, 2.53000000e+00],
#        [3.60892000e+03, 2.34000000e+00],
#        [5.31496000e+03, 2.57000000e+00],
#        [5.01969000e+03, 2.44000000e+00],
#        [5.01969000e+03, 2.44000000e+00],
#        [4.23228000e+03, 2.34000000e+00],
#        [5.01969000e+03, 2.44000000e+00],
#        [4.88845000e+03, 2.44000000e+00],
#        [4.56037000e+03, 2.37000000e+00],
#        [5.90551000e+03, 2.56000000e+00],
#        [4.52756000e+03, 2.39000000e+00],
#        [5.57743000e+03, 2.56000000e+00],
#        [4.33071000e+03, 2.53000000e+00],
#        [5.24934000e+03, 2.53000000e+00],
#        [5.74147000e+03, 2.69000000e+00],
#        [5.38058000e+03, 2.44000000e+00],
#        [5.24934000e+03, 2.44000000e+00],
#        [5.28215000e+03, 2.44000000e+00],
#        [5.57743000e+03, 2.56000000e+00],
#        [4.85564000e+03, 2.39000000e+00],
#        [4.26509000e+03, 2.34000000e+00],
#        [5.18373000e+03, 2.57000000e+00],
#        [5.34777000e+03, 2.57000000e+00],
#        [5.47900000e+03, 2.64000000e+00],
#        [4.72441000e+03, 2.31000000e+00],
#        [5.28215000e+03, 2.44000000e+00],
#        [5.51181000e+03, 2.44000000e+00],
#        [5.28215000e+03, 2.53000000e+00],
#        [4.65879000e+03, 2.37000000e+00],
#        [5.08530000e+03, 2.53000000e+00],
#        [5.15092000e+03, 2.57000000e+00],
#        [4.56037000e+03, 2.31000000e+00],
#        [4.46194000e+03, 2.31000000e+00],
#        [4.42913000e+03, 2.37000000e+00],
#        [4.65879000e+03, 2.39000000e+00],
#        [5.51181000e+03, 2.56000000e+00],
#        [5.74147000e+03, 2.64000000e+00],
#        [4.46194000e+03, 2.39000000e+00],
#        [4.36352000e+03, 2.34000000e+00],
#        [4.00262000e+03, 2.31000000e+00],
#        [4.85564000e+03, 2.39000000e+00],
#        [4.23228000e+03, 2.37000000e+00],
#        [4.79003000e+03, 2.57000000e+00],
#        [5.41339000e+03, 2.56000000e+00],
#        [5.18373000e+03, 2.39000000e+00],
#        [4.52756000e+03, 2.53000000e+00],
#        [5.21654000e+03, 2.57000000e+00],
#        [4.85564000e+03, 2.39000000e+00],
#        [4.00262000e+03, 2.34000000e+00],
#        [5.31496000e+03, 2.44000000e+00],
#        [5.24934000e+03, 2.44000000e+00],
#        [5.08530000e+03, 2.57000000e+00],
#        [5.01969000e+03, 2.39000000e+00],
#        [5.31496000e+03, 2.69000000e+00],
#        [5.34777000e+03, 2.57000000e+00],
#        [5.24934000e+03, 2.53000000e+00],
#        [4.85564000e+03, 2.39000000e+00],
#        [4.79003000e+03, 2.53000000e+00],
#        [4.85564000e+03, 2.57000000e+00],
#        [4.06824000e+03, 2.31000000e+00],
#        [4.33071000e+03, 2.39000000e+00],
#        [5.70866000e+03, 2.56000000e+00],
#        [5.41339000e+03, 2.64000000e+00],
#        [5.57743000e+03, 2.56000000e+00],
#        [4.79003000e+03, 2.37000000e+00],
#        [4.23228000e+03, 2.31000000e+00],
#        [5.41339000e+03, 2.53000000e+00],
#        [4.56037000e+03, 2.31000000e+00],
#        [3.57612000e+03, 2.34000000e+00],
#        [5.24934000e+03, 2.44000000e+00],
#        [4.69160000e+03, 2.39000000e+00],
#        [5.21654000e+03, 2.44000000e+00],
#        [4.95407000e+03, 2.44000000e+00],
#        [4.69160000e+03, 2.31000000e+00],
#        [4.46194000e+03, 2.31000000e+00],
#        [5.05249000e+03, 2.53000000e+00],
#        [5.38058000e+03, 2.56000000e+00],
#        [5.05249000e+03, 2.44000000e+00],
#        [5.47900000e+03, 2.69000000e+00],
#        [4.19948000e+03, 2.31000000e+00],
#        [5.47900000e+03, 2.44000000e+00],
#        [5.80709000e+03, 2.69000000e+00],
#        [5.24934000e+03, 2.57000000e+00],
#        [4.52756000e+03, 2.34000000e+00],
#        [4.69160000e+03, 2.37000000e+00],
#        [4.69160000e+03, 2.39000000e+00],
#        [4.26509000e+03, 2.34000000e+00],
#        [5.21654000e+03, 2.44000000e+00],
#        [4.82283000e+03, 2.57000000e+00],
#        [5.93832000e+03, 2.64000000e+00],
#        [5.18373000e+03, 2.44000000e+00],
#        [5.34777000e+03, 2.64000000e+00],
#        [5.74147000e+03, 2.64000000e+00],
#        [4.26509000e+03, 2.39000000e+00],
#        [5.70866000e+03, 2.69000000e+00],
#        [5.61024000e+03, 2.56000000e+00],
#        [5.34777000e+03, 2.56000000e+00],
#        [5.24934000e+03, 2.44000000e+00],
#        [4.06824000e+03, 2.37000000e+00],
#        [4.69160000e+03, 2.37000000e+00],
#        [5.70866000e+03, 2.56000000e+00],
#        [4.19948000e+03, 2.37000000e+00],
#        [4.39633000e+03, 2.31000000e+00],
#        [4.49475000e+03, 2.31000000e+00],
#        [5.15092000e+03, 2.44000000e+00],
#        [4.26509000e+03, 2.37000000e+00],
#        [4.69160000e+03, 2.39000000e+00],
#        [4.65879000e+03, 2.37000000e+00],
#        [4.36352000e+03, 2.34000000e+00],
#        [4.03543000e+03, 2.31000000e+00],
#        [4.59318000e+03, 2.37000000e+00],
#        [5.47900000e+03, 2.57000000e+00],
#        [4.95407000e+03, 2.44000000e+00],
#        [5.93832000e+03, 2.69000000e+00],
#        [5.80709000e+03, 2.56000000e+00],
#        [5.38058000e+03, 2.44000000e+00],
#        [5.05249000e+03, 2.53000000e+00],
#        [5.57743000e+03, 2.56000000e+00],
#        [4.39633000e+03, 2.34000000e+00],
#        [5.24934000e+03, 2.44000000e+00],
#        [5.77428000e+03, 2.64000000e+00],
#        [4.65879000e+03, 2.37000000e+00],
#        [4.52756000e+03, 2.31000000e+00],
#        [5.93832000e+03, 2.69000000e+00],
#        [4.59318000e+03, 2.34000000e+00],
#        [4.19948000e+03, 2.39000000e+00],
#        [4.98688000e+03, 2.44000000e+00],
#        [4.82283000e+03, 2.44000000e+00],
#        [5.70866000e+03, 2.64000000e+00],
#        [4.62598000e+03, 2.37000000e+00],
#        [4.92126000e+03, 2.57000000e+00],
#        [4.59318000e+03, 2.39000000e+00],
#        [4.69160000e+03, 2.39000000e+00],
#        [5.38058000e+03, 2.44000000e+00],
#        [5.01969000e+03, 2.39000000e+00],
#        [5.77428000e+03, 2.64000000e+00],
#        [4.26509000e+03, 2.34000000e+00],
#        [5.21654000e+03, 2.57000000e+00],
#        [5.77428000e+03, 2.69000000e+00],
#        [3.51050000e+03, 2.34000000e+00],
#        [4.72441000e+03, 2.44000000e+00],
#        [5.44619000e+03, 2.44000000e+00],
#        [5.31496000e+03, 2.57000000e+00],
#        [5.38058000e+03, 2.44000000e+00],
#        [4.92126000e+03, 2.37000000e+00],
#        [4.75722000e+03, 2.53000000e+00],
#        [4.19948000e+03, 2.39000000e+00],
#        [4.03543000e+03, 2.37000000e+00],
#        [5.47900000e+03, 2.56000000e+00],
#        [4.49475000e+03, 2.31000000e+00],
#        [5.24934000e+03, 2.44000000e+00],
#        [5.01969000e+03, 2.53000000e+00],
#        [5.21654000e+03, 2.57000000e+00],
#        [4.85564000e+03, 2.39000000e+00],
#        [5.93832000e+03, 2.69000000e+00],
#        [5.74147000e+03, 2.64000000e+00],
#        [4.42913000e+03, 2.37000000e+00],
#        [5.21654000e+03, 2.53000000e+00],
#        [3.57612000e+03, 2.34000000e+00],
#        [5.11811000e+03, 2.44000000e+00],
#        [5.47900000e+03, 2.56000000e+00],
#        [4.52756000e+03, 2.31000000e+00],
#        [4.36352000e+03, 2.39000000e+00],
#        [4.62598000e+03, 2.37000000e+00],
#        [5.44619000e+03, 2.44000000e+00],
#        [5.44619000e+03, 2.57000000e+00],
#        [5.34777000e+03, 2.44000000e+00],
#        [5.34777000e+03, 2.57000000e+00]])

# %% [markdown]
# A plot is usually the best way to meet the data.

# %%
import matplotlib.pyplot as plt

plt.scatter(*X.T)
plt.xlabel('Vp')
_ = plt.ylabel('Rho')

# %%
LITHS = ['limestone', 'dolomite', 'shale']

def lith_index(y):
    return [LITHS.index(lith) for lith in y]

fig, ax = plt.subplots()

scatter = ax.scatter(*X.T, c=lith_index(df['Lithology']))
ax.set_xlabel('Vp')
ax.set_ylabel('Rho')
handles, labels = scatter.legend_elements()
legend = ax.legend(handles = handles, labels = LITHS, title="Lithology")

# %% [markdown]
# ## A linear model: SVM
#
#
# The **support vector machine** is a reliable classifier.

# %%
from sklearn.svm import SVC

svc = SVC(kernel='linear')

clf = svc.fit(X, y)

y_pred = clf.predict(X)

# %%
fig, ax = plt.subplots()

scatter = ax.scatter(*X.T, c=lith_index(df['Lithology']), s= 80)
ax.scatter(*X.T, c=lith_index(y_pred), s=40, marker='x')
ax.set_xlabel('Vp')
ax.set_ylabel('Rho')
handles, labels = scatter.legend_elements()
legend = ax.legend(handles = handles, labels = LITHS, title="Lithology")

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y, y_pred)
# Out:
# 0.8130841121495327

# %%
# Is this a good score? It depends on context. Some tasks are very challenging, and it may be hard to achieve
# very high accuracy, other tasks are more simple and we should expect accuraies approaching 99%.
# It all depends. But did we do this evaluation the right way though? You can think a little about that!

# %% [markdown]
# **❓ What do we think? Are we satisfied?**
#
# <br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;

# %% [markdown]
# ## Scoring
#
# Scores matter in all machine learning tasks. It is very common to see people reporting only **accuracy** for classification tasks, or only **R<sup>2</sup>** for regression tasks. It is almost never enough to only look at (or report) the 'obvious' score -- especially for multiclass problems like this one, and especially when there is class imbalance.
#
# **This is one of the most important review papers in all of machine learning: [Raschka 2018](https://arxiv.org/abs/1811.12808). Read it and share it.**

# %%
df['Lithology'].value_counts()
# Out:
# Lithology
# shale        200
# dolomite     200
# limestone     28
# Name: count, dtype: int64

# %% [markdown]
# ### Confusion matrix
#
# This matrix, and the associated display, are a common way to look at the performance of the estimator.

# %%
from sklearn.metrics import ConfusionMatrixDisplay

_ = ConfusionMatrixDisplay.from_estimator(svc, X, y)

# %% [markdown]
# It's worth spending some time to understanding what the matrix is telling you. Think about true predictions, false positives, and false negatives.
#
# ### Classification report
#
# This report summarizes some of the information contained in the confusion matrix:

# %%
# precision: TP / TP + FP        # correctly pred. limestone / (corr. + falsely pred. limestone)
                                 # false positives are bad, like spam detection for mails
# recall:    TP / P              # probability of detection, correctly pred. limestone / actual nr. of limestone
                                 # missing a case is bad, like early cancer detection
# f1:        2 * Pr*Re / Pr + Re # harmonic mean of precision and recall, a measure of both at once 
# ma. avg:                       # score of class i, weighted equally, summed over all classes
# w. avg:                        # score of class i, weighted by number of instances of class i, summed over all classes

# %%
from sklearn.metrics import classification_report

print(classification_report(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     dolomite       0.78      0.94      0.85       200
#    limestone       1.00      0.46      0.63        28
#        shale       0.85      0.73      0.78       200
#
#     accuracy                           0.81       428
#    macro avg       0.88      0.71      0.76       428
# weighted avg       0.83      0.81      0.81       428

# %% [markdown]
# 💡 It's worth taking a look at exactly what **precision**, **recall**, **f1**, **macro** and **weighted** (formerly **micro**) mean.

# %% [markdown]
# ### Visualization
#
# We can also inspect the so-called **decision surface** to see why the model classifies the data as it does.

# %%
import numpy as np

fig, ax = plt.subplots()

x_min, x_max, y_min, y_max = (X[:,0].min() - 200, X[:,0].max() + 200, 
                              X[:,1].min() - 0.05, X[:,1].max() + 0.05
                             )
xx, yy = np.meshgrid(
    np.linspace(x_min, x_max, 1000),
    np.linspace(y_min, y_max, 1000)
)
grid = np.vstack([xx.ravel(), yy.ravel()]).T

zz = clf.predict(np.c_[xx.ravel(), yy.ravel()])
zz = np.array(lith_index(zz)).reshape(xx.shape)
ax.contourf(xx, yy, zz)

scatter = ax.scatter(*X.T, c=lith_index(df['Lithology']), edgecolor='k', s=30)
ax.set_xlabel('Vp')
ax.set_ylabel('Rho')
handles, labels = scatter.legend_elements()
legend = ax.legend(handles = handles, labels = LITHS, title="Lithology")

# %% [markdown]
# Sometimes there is also a domain-specific way to look at the results. For example, for wireline log data, we might like to look at a side-by-side comparison of the rock types.

# %% [markdown]
# ## Validation
#
# Now that we have touched upon different evaluation criteria, we need to address another issue: fairness. Our test was not fair.
#
# We should not train the model then check its accuracy only on that same training dataset. It's cheating, because in the future we'd like to predict on data that the model has never seen. So we should test the model on data it has never seen.
#
# Let's hold out some validation data, or 'blind' data.

# %%
# Training and testing on the same data is like giving you the exam to practice on before taking it.
# You learn that exam very well, but not necessarily the curriculum!

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((321, 2), (321,), (107, 2), (107,))

# %% [markdown]
# ### EXERCISE
#
# Now let's train a model _on only the training data_ and validate it properly _on only the test data_.
#
# **❓ Do we think the score will be better or worse than before?**

# %%
svc = SVC(kernel='linear')

svc.fit( ... )  # Replace the dots with the training data.

y_pred = svc.predict( ... )  # What will we predict on?

print(classification_report( ... ))  # What do we give the report function?

# %%
svc = SVC(kernel='linear')

svc.fit(X_train, y_train)

y_pred = svc.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     dolomite       0.71      0.95      0.81        43
#    limestone       0.33      0.20      0.25         5
#        shale       0.87      0.68      0.76        59
#
#     accuracy                           0.77       107
#    macro avg       0.64      0.61      0.61       107
# weighted avg       0.78      0.77      0.76       107

# %% [markdown]
# **❓ What do we need to think about when splitting? In other words: what is the most important thing about the test data?**
#
# &nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />
#
# First and foremost, the test data must look like data we expect in the future.
#
# We also need to think about:
#
# - **Independence** — can you shuffle the data without losing information?
# - **Identical distributions** — are both the train and test data from the same distribution?
# - **Reproducibility** — what can we do to make this reproducible?
# - **Stratification** — How can we deal with class imbalance?
#
# Can you demonstrate that the test sample is fair and reproducible?

# %%
# Independence part: - if your data is naturally grouped, e.g. multiple measurements from the same location
#                      or from the same subject, the model might learn location/subject-specific patterns,
#                      and not general patterns across locations/subjects.
#                    - if your data is a time series, the future is dependent on the past, splitting randomly
#                      will then let you 'look ahead' during training if you later test on past samples.

# Stratification part: we will touch upon that later if we have time

# %%
plt.scatter(*X_train.T, c=lith_index(y_train))
plt.scatter(*X_test.T, c=lith_index(y_test), edgecolor='r')
plt.xlabel('Vp')
_ = plt.ylabel('Rho')

# %%
import seaborn as sns

fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, figsize=(12,4))

sns.histplot(X_train[:, 0], stat='density', kde=True, alpha=0.3, linewidth=0.5, kde_kws={'bw_adjust':0.5}, legend=False, ax=ax0)
sns.histplot(X_test[:, 0], stat='density', kde=True, alpha=0.3, linewidth=0.5, kde_kws={'bw_adjust':0.5}, legend=False, ax=ax0)
ax1.set_xlabel('Vp')

sns.histplot(X_train[:, 1], stat='density', kde=True, alpha=0.3, linewidth=0.5, kde_kws={'bw_adjust':0.5}, legend=False, ax=ax1)
sns.histplot(X_test[:, 1], stat='density', kde=True, alpha=0.3, linewidth=0.5, kde_kws={'bw_adjust':0.5}, legend=False, ax=ax1)
_ = ax3.set_xlabel('Rho')

# %% [markdown]
# Let's do it in the proper reproducible way this time!

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1337)

svc = SVC(kernel='linear')
svc.fit(X_train, y_train)
y_pred = svc.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     dolomite       0.85      0.96      0.90        48
#    limestone       0.67      0.44      0.53         9
#        shale       0.85      0.80      0.82        50
#
#     accuracy                           0.84       107
#    macro avg       0.79      0.73      0.75       107
# weighted avg       0.84      0.84      0.83       107

# %% [markdown]
# ## A non-linear SVM model
#
# If we employ the **kernel trick** we can fit a nonlinear model. Scikit-learn's `SVC` actually uses this by default:

# %%
import matplotlib.colors as mcolors

svc = SVC()  # Default is kernel='rbf'
clf = svc.fit(X_train, y_train)
y_pred = clf.predict(X_test)

fig, ax = plt.subplots()

scatter = ax.scatter(*X_test.T, c=lith_index(y_test), s= 80)
ax.scatter(*X_test.T, c=np.array(lith_index(y_pred)), s=40, marker='x', norm=mcolors.Normalize(vmin=0, vmax=2))
ax.set_xlabel('Vp')
ax.set_ylabel('Rho')
handles, labels = scatter.legend_elements()
legend = ax.legend(handles = handles, labels = LITHS, title="Lithology")

# %% [markdown]
# The score is muuuuuuuuuuuch worse, especially for the minority class:

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     dolomite       0.85      0.96      0.90        48
#    limestone       0.00      0.00      0.00         9
#        shale       0.79      0.84      0.82        50
#
#     accuracy                           0.82       107
#    macro avg       0.55      0.60      0.57       107
# weighted avg       0.75      0.82      0.79       107
# C:\Users\MABJER\dev\MartinBjerke\intro-to-data-science\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\MABJER\dev\MartinBjerke\intro-to-data-science\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\MABJER\dev\MartinBjerke\intro-to-data-science\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
fig, ax = plt.subplots()

x_min, x_max, y_min, y_max = (X[:,0].min() - 200, X[:,0].max() + 200, 
                              X[:,1].min() - 0.05, X[:,1].max() + 0.05
                             )
xx, yy = np.meshgrid(
    np.linspace(x_min, x_max, 1000),
    np.linspace(y_min, y_max, 1000)
)
grid = np.vstack([xx.ravel(), yy.ravel()]).T

zz = clf.predict(np.c_[xx.ravel(), yy.ravel()])
zz = np.array(lith_index(zz)).reshape(xx.shape)
ax.contourf(xx, yy, zz, norm=mcolors.Normalize(vmin=0, vmax=2))

scatter = ax.scatter(*X.T, c=lith_index(df['Lithology']), edgecolor='k', s=30)
ax.set_xlabel('Vp')
ax.set_ylabel('Rho')
handles, labels = scatter.legend_elements()
legend = ax.legend(handles = handles, labels = LITHS, title="Lithology")

# %% [markdown]
# **❓ What could the problem be?**
#
# <br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;

# %% [markdown]
# ### Scale matters
#
# Our two features operate on *very* different scales! (m/s and g/cm<sup>3</sup>). Some models do not mind this, others do. SVM is one of those! You can get a numerical feel for it by forcing equal axes while scatterplotting the data:

# %%
plt.scatter(*X_train.T)
plt.axis('equal')
plt.xlabel('Vp')
_ = plt.ylabel('Rho')

# %% [markdown]
# ## Standardize the data
#
# It's essential to train SVMs on scaled data, usually the Z-scores of your data, i.e. zero mean, unit variance. This ensures that the different scales of the features is not causing a problem.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(X_train)

X_train_sc = scaler.transform(X_train)
X_test_sc = scaler.transform(X_test)

# %% [markdown]
# This doesn't change how the data are relatively distributed:

# %%
fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(12,4))
ax0.scatter(*X_train.T)
ax1.scatter(*X_train_sc.T)
ax0.set_xlabel('Vp')
ax0.set_ylabel('Rho')
ax1.set_xlabel('Scaled Vp')
_ = ax1.set_ylabel('Scaled Rho')

# %% [markdown]
# But it dramatically changes how they are distributed in absolute terms:

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15, 5))
sns.kdeplot(X_train[:, [1,0]], ax=axs[0])
sns.kdeplot(X_train_sc[:, [1,0]], ax=axs[1])
axs[0].legend(['Vp', 'Rho'])
_ = axs[1].legend(['Scaled Vp', 'Scaled Rho'])

# %% [markdown]
# ### EXERCISE
#
# Re-fit the **linear** model and look at the scores.

# %%
svc = SVC(kernel='linear')

svc.fit(X_train_sc, y_train)

y_pred = svc.predict(X_test_sc)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     dolomite       0.92      0.94      0.93        48
#    limestone       1.00      0.89      0.94         9
#        shale       0.92      0.92      0.92        50
#
#     accuracy                           0.93       107
#    macro avg       0.95      0.92      0.93       107
# weighted avg       0.93      0.93      0.93       107

# %% [markdown]
#                                                  Previous report:
#
# |   | precision    | recall | f1-score | support |
# | ---- | ----- | ------- | ------ | -------|
# | dolomite | 0.85  | 0.96    | 0.90 | 48 |
# | limestone | 0.67 | 0.44    | 0.53 | 9 |
# | shale | 0.85   | 0.8    | 0.82 | 50 |
# | | | |  |  |
# | accuracy |  |  | 0.84 | 107 |
# | macro avg | 0.79 | 0.73 | 0.75 | 107  |
# | weighted avg | 0.84 | 0.84 | 0.83 | 107 |

# %% [markdown]
# Solving one problem gives us a new one. Now we have a new pitfall: it is essential to scale the data now before inference -- although the model will happily make (terrible) predictions.

# %%
X_train[-1, :], X_train_sc[-1, :]
# Out:
# (array([1672.118664  ,    2.28900003]), array([-2.70496844, -1.14817713]))

# %%
svc.predict(X_train[-1,:].reshape(1,-1)), svc.predict(X_train_sc[-1,:].reshape(1,-1))
# Out:
# (array(['dolomite'], dtype=object), array(['shale'], dtype=object))

# %% [markdown]
# This is known as an "out of distribution" or OOD error, and it's a classic pitfall in machine learning.

# %% [markdown]
# ## Put everything in a pipeline
#
# This is the most flexible way to compose data pipelines in `sklearn`. It is usually better than implementing everything individually in a stepwise manner.
#
# For now, it won't change anything.

# %%
from sklearn.pipeline import make_pipeline

pipe = make_pipeline(StandardScaler(), SVC(kernel='linear'))

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     dolomite       0.92      0.94      0.93        48
#    limestone       1.00      0.89      0.94         9
#        shale       0.92      0.92      0.92        50
#
#     accuracy                           0.93       107
#    macro avg       0.95      0.92      0.93       107
# weighted avg       0.93      0.93      0.93       107

# %% [markdown]
# And now the nonlinear SVM is basically identical to the linear one:

# %%
pipe = make_pipeline(StandardScaler(), SVC())

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     dolomite       0.94      0.94      0.94        48
#    limestone       1.00      0.89      0.94         9
#        shale       0.92      0.94      0.93        50
#
#     accuracy                           0.93       107
#    macro avg       0.95      0.92      0.94       107
# weighted avg       0.94      0.93      0.93       107

# %% [markdown]
# ## Hyperparameter tuning
#
# Most algorithms have **hyperparameters** which control how the algorithm learns -- and which often implement some kind of **regularization**. This means different things for different algorithms, but in general it involves simplifying or smoothing the model in some way.
#
# For the [support vector machine](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html), there is a parameter `C` to control the model complexity (an SVM tries to satistfy two critera during optimization: wide margins (how far from the linear separation to the nearest point in each class) and few missclassified instances. Sometimes these constraints compete, and `C` allows us to "select" which criterion the model should prioritize. High `C` means high complexity and low regularization, see this [stackoverflow thread](https://stats.stackexchange.com/a/159051) for a nice visualization of what `C`does).

# %%
# hyperparameters are set by the user, and can vastly affect the performance of a model. One such hyperparam. can be
# the regularization strength of the hinge loss of our SVM (i.e. how much should we penalize our SVM model for
# misclassifying vs increasing the margin).

# %% [markdown]
# ### Looping!
#
# Let's write a loop to step over values of the regularization parameter `C`. Start with:
#
#     C = np.logspace(-3, 5, 17)
#     mean_val, mean_train = [], []
#     for Ci in C:
#         # Instantiate the pipeline, using `SVC(C=Ci)`.
#         # Get the f1_score for both train and test sets.
#         # Gather these scores in two lists.
#
# When you have 2 lists of mean scores, plot them and compare how they vary with C. Put the x-axis on a log scale with `plt.xscale('log')`

# %%
# Why do we use logspace? This allows us to initially search a large space quickly (0.0001 is very different from 100).
# If we wish to refine it, we could do that later (though for many models, the difference between 0.01 and 0.05 is 
# not thaaat big).

# %%
from sklearn.metrics import f1_score

C = np.logspace(-3, 5, 17)

mean_val, mean_train = [], []
for Ci in C:
    pipe = make_pipeline(StandardScaler(), SVC(C=Ci))
    pipe.fit(X_train, y_train)
    y_pred = pipe.predict(X_test)
    mean_val.append(f1_score(y_test, y_pred, average='weighted'))
    y_pred = pipe.predict(X_train)
    mean_train.append(f1_score(y_train, y_pred, average='weighted'))

plt.plot(C, mean_val, label='Validation')
plt.plot(C, mean_train, c='r', label='Training')
plt.xlabel('C')
plt.ylabel('weighted f1-score')
plt.title('Model performance as function of hyperparameter')
plt.xscale('log')
plt.ylim(1.0, 0.65)
_ = plt.legend()

# %% [markdown]
# **❓ Do you see a potential issue here?**
#
# <br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;<br />&nbsp;
#
# Sometimes you will get a lucky test split, sometimes not. This feels a bit aribtrary. And we might overfit this model selection process to the particular test set that we have.

# %%
# To select the hyperparam. as just mentioned, one might first consider training different models
# with different hyperparams., then checking their performance on the test set. This however, "leaks" information
# from the test set into our training routine! Essentially, you as a user is overfitting to the test set. In other words, 
# you need a third set, validation set! Now you're starting to partition data into many parts, and performance can 
# depend on how the random split occur. Cross-validation attempts to correct this!

# https://scikit-learn.org/stable/modules/cross_validation.html#computing-cross-validated-metrics

# %% [markdown]
# ## Cross validation
#
# Instead of choosing a single holdout set for evaluation, we can choose many. This is useful for tuning hyperparameters, for example.
#
# But then we have more ways to leak information into our evaluation, so it is smart to continue to hold out our `val` set.
#
# The other catch is that we now must use a pipeline, otherwise we leak information in the scaling of the data.
#
# Fair evaluation is hard!

# %% [markdown]
# But now we can use folded cross-validation in a safe way:

# %%
from sklearn.model_selection import cross_validate, StratifiedKFold
#from sklearn.metrics import make_scorer

pipe = make_pipeline(StandardScaler(), SVC(C=0.1))
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42) 
# StratifiedKFold is useful for handling potential class imbalanced splits!

cross_validate(pipe,
               X_train, y_train,
               scoring='f1_weighted',
               cv=skf,
               return_train_score=True,
               # Also useful: groups
              )
# Out:
# {'fit_time': array([0.00400448, 0.00100231, 0.0020256 , 0.00200605, 0.00205541]),
#  'score_time': array([0.00399566, 0.00200319, 0.00200868, 0.00200701, 0.00205541]),
#  'test_score': array([0.81680449, 0.89941406, 0.87792969, 0.84570312, 0.8555791 ]),
#  'train_score': array([0.84841807, 0.8717864 , 0.83308833, 0.83729494, 0.88475887])}

# %% [markdown]
# Notice that we no longer use `test` during the model fitting process.

# %% [markdown]
# ### EXERCISE
#
# Use cross-validation in the loop over values of `C`. Start with:
#
#     C = np.logspace(-3, 5, 17)
#     mean_val, mean_train = [], []
#     for Ci in C:
#         # Instantiate the pipeline, using `SVC(C=Ci)`.
#         # Do the cross validation model fits with `cross_validate()`.
#         # Gather the means of the test and train scores.
#
# Then make the plot, as before.

# %%
mean_val, mean_train = [], []
for Ci in C:
    pipe = make_pipeline(StandardScaler(), SVC(C=Ci))
    cross_val = cross_validate(pipe, X_train, y_train, scoring='f1_weighted', cv=skf, return_train_score=True)
    mean_val.append(np.mean(cross_val['test_score']))
    mean_train.append(np.mean(cross_val['train_score']))

C_opt = C[np.argmax(mean_val)]

plt.plot(C, mean_val, label='Validation')
plt.plot(C, mean_train, c='r', label='Training')
plt.fill_between(C, mean_val, mean_train, alpha=0.2, color='grey')
plt.xlabel('C')
plt.ylabel('cross-validated weighted f1-score')
plt.title('Model performance as function of hyperparameter')
plt.axvline(C_opt, c='k', lw=0.67)
plt.text(1.1*C_opt, 0.87, f"← optimal C={C_opt:.1f}")
plt.xscale('log')
plt.ylim(1, 0.75)
_ = plt.legend()

# %%
# Arguably, this can be interpreted in the context of the bias-variance tradeoff. A SVM with low C will be allowed very
# large margins, and will misclassify a lot, leading to a classifier that in reality doesn't capture the relationships in
# the data (high bias). On the contrary, high C will penalize misclassifications, but the model might overfit to particular
# points that might not be generalizable, i.e. the hallmark of high variance. The sweetspot between these two C's is our goal!

# %% [markdown]
# ## Explore the model zoo!

# %% [markdown]
# ### EXERCISE
#
# - Add `Vs` (shear velocity) to the features and see if it improves the prediction quality.
# - Choose another algorithm to try a prediction with, and implement it in a pipeline.
# - Choose a hyperparameter of the new algorithm and tune it. (If you have done this kind of thing before, try tuning 2 or 3 hyperparameters with grid or random search.)

# %% [markdown]
# ## Test
#
# When you have tuned the predictor and are satisfied that it is as good as it can be, you can test your prediction power.

# %%
C_opt = C[np.argmax(mean_val)]
C_opt
C_opt = 5.0 # Alternatively, use C_opt = 5.0, which you get from a more refined search space

# %%
pipe = make_pipeline(StandardScaler(), SVC(C=C_opt))

pipe.fit(X_train, y_train)
                    
y_pred = pipe.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     dolomite       0.94      0.92      0.93        48
#    limestone       1.00      0.89      0.94         9
#        shale       0.90      0.94      0.92        50
#
#     accuracy                           0.93       107
#    macro avg       0.95      0.92      0.93       107
# weighted avg       0.93      0.93      0.93       107

# %% [markdown]
# Compare with the model with default `C`:

# %%
pipe = make_pipeline(StandardScaler(), SVC())

pipe.fit(X_train, y_train)
                    
y_pred = pipe.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     dolomite       0.94      0.94      0.94        48
#    limestone       1.00      0.89      0.94         9
#        shale       0.92      0.94      0.93        50
#
#     accuracy                           0.93       107
#    macro avg       0.95      0.92      0.94       107
# weighted avg       0.94      0.93      0.93       107

# %%
# Are we satisfied here? Have we overfit our model to the f1-score with our hyperparameter tuning? 
# Diffuclt to say ad hoc, that's why we must decide on the evaluation criteria in the beginning.
# If we get cold feet now and select the model with C=1 (default), we are overfitting ourselves
# to the test data, and hence cheating! Our model is C=C_opt!

# %% [markdown]
# If you are satisfied (think hard about what this means... you really have to decide before you start the model fitting process) then you are ready to fit the final model. If not, you must start all over again.

# %% [markdown]
# ## Using this model
#
# We do not want to use this model &mdash; if we like its performance then we should now retrain it on all the data. Presumably, this new model will be at least as good as the one trained on the training set, we just don't have a way to check it now 😬

# %%
scaler = StandardScaler().fit(X)
X_ = scaler.transform(X)
svc = SVC(C=C_opt).fit(X_, y)

# %% [markdown]
# There is no way for us to test this model, but we should monitor it in production.

# %% [markdown]
# <hr />
#
# <p style="color:gray"> adapted from &copy; 2025 Matt Hall / Equinor CC BY.</p>
